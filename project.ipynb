# %%
import pandas as pd
import numpy as np
df = pd.read_csv("shopping_behavior.csv")

# %% [markdown]
# ## A. Загрузка и первичный обзор

# %% [markdown]
# # B. Обработка данных

# %% [markdown]
# ## 1 задание

# %% [markdown]
# ## 2 задание

# %% [markdown]
# ## Cтатистика данных

# %% [markdown]
# # C. Визуализация данных
